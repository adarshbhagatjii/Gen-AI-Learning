# %%
# PREDICTION WITH TRAINED ANN MODEL
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np

# %%
# load the trained model, scaler, pickle, onehot
model=load_model('model.h5')

# load the encoders and scaler
with open('onehot_encoder_geo.pk1', 'rb')as file:
    label_encoder_geo=pickle.load(file)
    
with open('label_encoder_gender.pk1', 'rb')as file:
    label_encoder_gender=pickle.load(file)
    
with open('scaler.pk1', 'rb')as file:
    scaler=pickle.load(file)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Example input data
input_data={
    'CreditScore':750,
    'Geography':'France',
    'Gender':'Male',
    'Age':45,
    'Tenure':2,
    'Balance':6000,
    'NumOfProducts':3,
    'HasCrCard':1,
    'IsActiveMember':1,
    'EstimatedSalary':5000
}

# %%
# One-hot encode 'Geography'
geo_encoded=label_encoder_geo.transform([[input_data['Geography']]]).toarray()
geo_encoded_df=pd.DataFrame(geo_encoded, columns=label_encoder_geo.get_feature_names_out(['Geography']))
geo_encoded_df
# Out:
# f:\QSP\Gen AI\deeplearning\DLENV\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
# Here out input data is in the key_value format, so we have to convert it into dataframe before use
input_df=pd.DataFrame([input_data])
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          750    France   Male   45       2     6000              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1             5000

# %%
# #Encode categorical Variables
input_df['Gender']=label_encoder_gender.transform(input_df['Gender'])
input_df
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          750    France       1   45       2     6000              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1             5000

# %%
# Concatination of one hot encoded
input_df=pd.concat([input_df.drop("Geography", axis=1), geo_encoded_df], axis=1)
input_df
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          750       1   45       2     6000              3          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1             5000               1.0                0.0
#
#    Geography_Spain
# 0              0.0

# %%
# Scaling the input data
input_scaled=scaler.transform(input_df)
input_scaled
# Out:
# array([[ 1.03021428,  0.91360328,  0.58261671, -1.03249572, -1.12585605,
#          2.54529536,  0.64506294,  0.96934842, -1.66205347,  1.00262813,
#         -0.57961128, -0.57710974]])

# %%
# Prediction or predict the churn
prediction=model.predict(input_scaled)
prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# array([[0.70101017]], dtype=float32)

# %%
# probaility of the prediction
prediction_prob= prediction[0][0]
prediction_prob
# Out:
# np.float32(0.70101017)

# %%
if prediction_prob>0.5:
    print("The customer is likely to churn.")
else:
    print("The customer is not likely to churn")
# Out:
# The customer is likely to churn.
